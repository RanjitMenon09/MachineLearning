# %% [markdown]
# ### POS Tagging Library

# %%
# !pip install nltk
# !pip install pandas
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: pandas in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\ranjit09\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Using tokenizer

# %%
from nltk import word_tokenize
sentence = "The greatest glory in living lies not in never falling, but in rising every time we fall."
word_tokens = word_tokenize(sentence)
print(word_tokens)
# Out:
# ['The', 'greatest', 'glory', 'in', 'living', 'lies', 'not', 'in', 'never', 'falling', ',', 'but', 'in', 'rising', 'every', 'time', 'we', 'fall', '.']

# %% [markdown]
# ### Using POS Tagger

# %%
from nltk import pos_tag 
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
tagged_sentence = pos_tag(word_tokenize(sentence))
print(tagged_sentence)
# Out:
# [('The', 'DT'), ('greatest', 'JJS'), ('glory', 'NN'), ('in', 'IN'), ('living', 'VBG'), ('lies', 'NNS'), ('not', 'RB'), ('in', 'IN'), ('never', 'RB'), ('falling', 'VBG'), (',', ','), ('but', 'CC'), ('in', 'IN'), ('rising', 'VBG'), ('every', 'DT'), ('time', 'NN'), ('we', 'PRP'), ('fall', 'VBP'), ('.', '.')]

# %% [markdown]
# ### Get Tagset help

# %%
nltk.help.upenn_tagset('VBD')  #give more details on the parts of speech displayed as part of the pos_tag abbrevation
# Out:
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...

# %% [markdown]
# ### Using a text file perform lab work from nlp project

# %%
with open('files/LabE_5.txt','r') as file:
    content = file.read()

#print(content)

# %%
#For each word in the sentence, tag/ markthe corresponding POS using any POS tagger
import nltk
from nltk.corpus import stopwords
from string import punctuation
import pandas as pd
nltk.download('stopwords')


tokens = nltk.word_tokenize(content)

stop_words = stopwords.words('english')

filtered_tokens = [token for token in tokens if token not in punctuation]

pos_tags = nltk.pos_tag(filtered_tokens)

#df  = pd.DataFrame(pos_tags,columns=['word','tags'])
#pivot_table = pd.crosstab(index=df['word'],columns=df['tags'])

print(pos_tags)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('Great', 'NNP'), ('buy', 'NN'), ('always', 'RB'), ('go', 'VBP'), ('with', 'IN'), ('white', 'JJ'), ('dark', 'NN'), ('colors', 'NNS'), ('melt', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('Florida', 'NNP'), ('sun', 'NN'), ('Experience', 'NN'), ('over', 'IN'), ('Cordless', 'NNP'), ('is', 'VBZ'), ('cool', 'JJ'), ('too', 'RB'), ('Awesome', 'JJ'), ('product', 'NN'), ('...', ':'), ('love', 'VB'), ('it', 'PRP'), ('Love', 'VB'), ('it', 'PRP'), ('easy', 'JJ'), ('to', 'TO'), ('put', 'VB'), ('up', 'RP'), ('as', 'RB'), ('well', 'RB'), ('These', 'DT'), ('go', 'VB'), ('up', 'RP'), ('very', 'RB'), ('easily', 'RB'), ('and', 'CC'), ('I', 'PRP'), ('love', 'VBP'), ('the', 'DT'), ('cordless', 'NN'), ('feature', 'NN'), ('Color', 'NNP'), ('is', 'VBZ'), ('perfect', 'JJ'), ('too', 'RB'), ('When', 'WRB'), ('using', 'VBG'), ('the', 'DT'), ('rod', 'NN'), ('to', 'TO'), ('open', 'VB'), ('the', 'DT'), ('blind', 'NN'), ('the', 'DT'), ('rod', 'NN'), ('gets', 'VBZ'), ('stuck', 'VBN'), ('and', 'CC'), ('snaps', 'VBZ'), ('back', 'RB'), ('to', 'TO'), ('the', 'DT'), ('original', 'JJ'), ('position', 'NN'), ('It', 'PRP'), ('requires', 'VBZ'), ('frequent', 'JJ'), ('adjustments', 'NNS'), ('but', 'CC'), ('ultimately', 'RB'), ('works', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('top', 'JJ'), ('brackets', 'NNS'), ('was', 'VBD'), ('broken', 'VBN'), ('how', 'WRB'), ('do', 'VBP'), ('I', 'PRP'), ('get', 'VB'), ('a', 'DT'), ('replacement', 'NN'), ('I', 'PRP'), ('love', 'VBP'), ('the', 'DT'), ('sting', 'VBG'), ('free', 'JJ'), ('pushing', 'VBG'), ('and', 'CC'), ('pulling', 'VBG'), ('to', 'TO'), ('adjust', 'VB'), ('the', 'DT'), ('blind', 'NN'), ('height', 'VBD'), ('No', 'NNP'), ('tangles', 'NNS'), ('Very', 'RB'), ('hands', 'VBZ'), ('free', 'JJ'), ('Nothing', 'NNP'), ('getting', 'VBG'), ('stuck', 'VBN'), ('And', 'CC'), ('fast', 'JJ'), ('Very', 'NNP'), ('agitating', 'VBG'), ('to', 'TO'), ('order', 'NN'), ('a', 'DT'), ('25', 'CD'), ('x', 'NN'), ('72', 'CD'), ('inch', 'NN'), ('blind', 'IN'), ('a', 'DT'), ('replacement', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('comes', 'VBZ'), ('in', 'IN'), ('the', 'DT'), ('box', 'NN'), ('that', 'WDT'), ('says', 'VBZ'), ('25x72', 'CD'), ('but', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('actually', 'RB'), ('measuring', 'VBG'), ('at', 'IN'), ('24.5', 'CD'), ('x', 'JJ'), ('72', 'CD'), ('and', 'CC'), ('that', 'DT'), ('little', 'JJ'), ('bit', 'NN'), ('throws', 'VBZ'), ('it', 'PRP'), ('all', 'DT'), ('off', 'RP'), ('Contacted', 'NNP'), ('walmart', 'NN'), ('and', 'CC'), ('they', 'PRP'), ('contacted', 'VBD'), ('seller', 'NN'), ('but', 'CC'), ('never', 'RB'), ('heard', 'VBD'), ('anything', 'NN'), ('from', 'IN'), ('seller', 'NN'), ('so', 'RB'), ('got', 'VBD'), ('a', 'DT'), ('refund', 'NN'), ('Just', 'NNP'), ('agitating', 'NN'), ('I', 'PRP'), ('was', 'VBD'), ('so', 'RB'), ('happy', 'JJ'), ('to', 'TO'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('order', 'NN'), ('these', 'DT'), ('blinds', 'NNS'), ('for', 'IN'), ('my', 'PRP$'), ('narrow', 'JJ'), ('windows', 'NNS'), ('with', 'IN'), ('out', 'RP'), ('special', 'JJ'), ('ordering', 'VBG'), ('The', 'DT'), ('first', 'JJ'), ('set', 'NN'), ('went', 'VBD'), ('up', 'RB'), ('well', 'RB'), ('but', 'CC'), ('the', 'DT'), ('2nd', 'CD'), ('set', 'NN'), ('drooped', 'VBD'), ('I', 'PRP'), ('tried', 'VBD'), ('to', 'TO'), ('re-adjust', 'VB'), ('the', 'DT'), ('placement', 'NN'), ('of', 'IN'), ('the', 'DT'), ('bracket', 'NN'), ('to', 'TO'), ('see', 'VB'), ('if', 'IN'), ('that', 'DT'), ('would', 'MD'), ('help', 'VB'), ('and', 'CC'), ('the', 'DT'), ('bottom', 'JJ'), ('support', 'NN'), ('of', 'IN'), ('the', 'DT'), ('bracket', 'NN'), ('snapped', 'VBD'), ('off', 'RB'), ('Now', 'RB'), ('I', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('privacy', 'NN'), ('between', 'IN'), ('my', 'PRP$'), ('front', 'NN'), ('window', 'NN'), ('and', 'CC'), ('the', 'DT'), ('street', 'NN'), ('The', 'DT'), ('blind', 'NN'), ('was', 'VBD'), ('suppose', 'JJ'), ('to', 'TO'), ('have', 'VB'), ('been', 'VBN'), ('with', 'IN'), ('2', 'CD'), ("''", "''"), ('Slat', 'NNP'), ('The',  ...

# %% [markdown]
# ### Using lemmatization to the above token

# %%
nltk.download('wordnet')
nltk.download('universal_tagset')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wn_pos_tags = {'N':'n','V':'v','J':'a','R':'r'}

lemmas = []
for token, pos in pos_tags:   
    pos = nltk.map_tag('en-ptb', 'universal',pos) 
    wn_pos = wn_pos_tags.get(pos[0], None)
    if wn_pos is None:
        lemmas.append(token)
    else:
        lemma = lemmatizer.lemmatize(token, pos=wn_pos)
        lemmas.append(lemma)

#print(lemmas)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\ranjit09\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# ### Extract Product descriptors and generate sentiments
#
# #### Sentiment Score return polarity and subjectivity
# #### Polarity will return from 0 to 1 and represent sentiment, if it is close to 0, it means a negative sentiment and close to 1, it means a positive sentiment, we got 0.30 below, which means it is more of negative sentiment
# #### Subjectivity tell us, if it is a subjective statement or objective statement, subjective express a personnel opinion or belief and objective reprsents facts or information,
# #### in this a 0 represent an objective statement and 1 represents a subjective statement, in our case it is more subjective statement as it is 0.56

# %%
#!pip install textblob
from textblob import TextBlob

tokens = nltk.word_tokenize(content)
tagged_tokens = pos_tag(tokens)

#extract all the adjectives
adjectives = [token for token,pos in tagged_tokens if pos == 'JJ']

#generate a summary
text = TextBlob(content)

#print("All Adjectives : ", adjectives)
print("------------------------------")
print("Sentiment Score : ", text.sentiment)
# Out:
# ------------------------------
# Sentiment Score :  Sentiment(polarity=0.30984171125193105, subjectivity=0.5654798161953521)
